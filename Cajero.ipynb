# %% [markdown]
# <a href="https://colab.research.google.com/github/Puentes02/Mat-Aplicadas/blob/main/Cajero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Jose Alejandro morera**
# ## **Juan Esteban Martienz**
# ## **Emanuel Puentes**

# %%
class CajeroAutomatico:
    def __init__(self, pin_correcto, saldo_inicial=1000000):
        self.pin_correcto = pin_correcto
        self.saldo = saldo_inicial

    def autenticar(self, pin):
        return pin == self.pin_correcto

    def consultar_saldo(self):
        return f"Saldo actual: ${self.saldo}"

    def depositar(self, cantidad):
        if cantidad > 0:
            self.saldo += cantidad
            return f"Depósito exitoso. Nuevo saldo: ${self.saldo}"
        return "Cantidad no válida para depósito."

    def retirar(self, cantidad):
        if 0 < cantidad <= self.saldo:
            self.saldo -= cantidad
            return f"Retiro exitoso. Nuevo saldo: ${self.saldo}"
        return "Fondos insuficientes o cantidad no válida."

def menu():
    cajero = CajeroAutomatico(pin_correcto="1234")
    intentos = 3

    while intentos > 0:
        pin = input("Ingrese su PIN: ")
        if cajero.autenticar(pin):
            while True:
                print("\n1. Consultar saldo\n2. Depositar\n3. Retirar\n4. Salir")
                opcion = input("Seleccione una opción: ")
                if opcion == "1":
                    print(cajero.consultar_saldo())
                elif opcion == "2":
                    monto = float(input("Ingrese el monto a depositar: "))
                    print(cajero.depositar(monto))
                elif opcion == "3":
                    monto = float(input("Ingrese el monto a retirar: "))
                    print(cajero.retirar(monto))
                elif opcion == "4":
                    print("Gracias por usar el cajero. ¡Hasta luego!")
                    break
                else:
                    print("Opción no válida.")
            break
        else:
            intentos -= 1
            print(f"PIN incorrecto. Intentos restantes: {intentos}")

    if intentos == 0:
        print("Demasiados intentos fallidos. Tarjeta bloqueada.")

if __name__ == "__main__":
    menu()

    def autenticar(self, pin):
        return pin == self.pin_correcto

    def consultar_saldo(self):
        return f"Saldo actual: ${self.saldo}"

    def depositar(self, cantidad):
        if cantidad > 0:
            self.saldo += cantidad
            return f"Depósito exitoso. Nuevo saldo: ${self.saldo}"
        return "Cantidad no válida para depósito."

    def retirar(self, cantidad):
        if 0 < cantidad <= self.saldo:
            self.saldo -= cantidad
            return f"Retiro exitoso. Nuevo saldo: ${self.saldo}"
        return "Fondos insuficientes o cantidad no válida."

def menu():
    cajero = CajeroAutomatico(pin_correcto="1234")
    intentos = 3

    while intentos > 0:
        pin = input("Ingrese su PIN: ")
        if cajero.autenticar(pin):
            while True:
                print("\n1. Consultar saldo\n2. Depositar\n3. Retirar\n4. Salir")
                opcion = input("Seleccione una opción: ")
                if opcion == "1":
                    print(cajero.consultar_saldo())
                elif opcion == "2":
                    monto = float(input("Ingrese el monto a depositar: "))
                    print(cajero.depositar(monto))
                elif opcion == "3":
                    monto = float(input("Ingrese el monto a retirar: "))
                    print(cajero.retirar(monto))
                elif opcion == "4":
                    print("Gracias por usar el cajero. ¡Hasta luego!")
                    break
                else:
                    print("Opción no válida.")
            break
        else:
            intentos -= 1
            print(f"PIN incorrecto. Intentos restantes: {intentos}")

    if intentos == 0:
        print("Demasiados intentos fallidos. Tarjeta bloqueada.")


if __name__ == "__main__":
    menu()
# Out:
# Ingrese su PIN: 1234
#
# 1. Consultar saldo
# 2. Depositar
# 3. Retirar
# 4. Salir
# Seleccione una opción: 1
# Saldo actual: $1000000
#
# 1. Consultar saldo
# 2. Depositar
# 3. Retirar
# 4. Salir
# Seleccione una opción: 2
# Ingrese el monto a depositar: 500000
# Depósito exitoso. Nuevo saldo: $1500000.0
#
# 1. Consultar saldo
# 2. Depositar
# 3. Retirar
# 4. Salir
# Seleccione una opción: 1
# Saldo actual: $1500000.0
#
# 1. Consultar saldo
# 2. Depositar
# 3. Retirar
# 4. Salir
# Seleccione una opción: 4
# Gracias por usar el cajero. ¡Hasta luego!
# Ingrese su PIN: 111111
# PIN incorrecto. Intentos restantes: 2
# Ingrese su PIN: 1
# PIN incorrecto. Intentos restantes: 1
# Ingrese su PIN: 1
# PIN incorrecto. Intentos restantes: 0
# Demasiados intentos fallidos. Tarjeta bloqueada.
