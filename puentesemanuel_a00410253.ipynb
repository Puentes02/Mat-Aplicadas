# %% [markdown]
# <a href="https://colab.research.google.com/github/Puentes02/Mat-aplicadas/blob/main/puentesemanuel_a00410253.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ####Mi nombre es Emanuel, nací el 2 de Mayo del 2007 en Cali. Desde pequeño, he sido una persona curiosa y alegre, lo me ha llevado a explorar diferentes deportes a lo largo de mi vida. Ahora mismo, estoy estudiando ingenieria industrial y aspiro a ser un profecinal con muchos conocimientos los cuales pueda ponerlos en practica en el negocio de mis papas.
# ![yo peque.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ####**Mis canciones favoritas son:**
# >*Me gustas cc - Roa*
# >>*Velda - Bad Bunny*
# >>>*Eta - Roa, Luar, De la rose*
# >>>>*2k16 - Bryant, Omar*
# >>>>>*Yo se - Yan Block*

# %% [markdown]
# ###**Tabla de mis materias favoritas**
#
# |Materia|Razon|
# |-|-|
# |Aplicadas|Porque me gustaria aprender como funcian diferentes lenguajes|
# |Fitness|Porque me distrae de las oytras materias|
# |Ingles|Porque el profesor hace actividades muy dinamicas|

# %% [markdown]
# ##**Ecuaciones que cambiaron el mundo**
# ###**1. Pythagoras theorem**
# $c^2=a^2+b^2$
#
# ###**2. Logarithms**
# $log xy = log x + log y$
#
#
# ###**3. Calculus**
# $\dfrac{df}{dt}= \displaystyle \lim_{ \to 0}=\dfrac{f(t+h)-f(t)}{h}$
#
# ###**4. Law of gravity**
# $F= G \dfrac{m^1 m^2}{r^2}$
#
# ###**5. The square root of minus one**
# $i^2=-1$
#
# ###**6. Eulers formula for polyhedra**
# $V-E+F=2$
#
# ###**7. Normal distribution**
# $\Phi(x)=\dfrac{1}{\sqrt2πp}c^\dfrac{h}{k}$
#
# ###**8. Wave equation**
# $\dfrac{\partial^2 u}{\partial t^2} = c^2 \dfrac{\partial^2 u}{\partial x^2}$
#
# ###**9. Fourier transform**
#
# $f(w) = \int_{\infty}^{\infty} f(x) e^{-2πixw}  dx$
#
# ###**10. Navier-stokes equation**
# $p (\dfrac{\partial v}{\partial t}+ V \cdot \bigtriangledown V)= -\bigtriangledown p \bigtriangledown \cdot T + f$
#
# ###**11. Maxwells equiations**
# #####$\bigtriangledown \cdot E =0$
# #####$\bigtriangledown × E =\dfrac {-1}{c} \dfrac{\partial H}{\partial t}$
# #####$\bigtriangledown \cdot H =0$
# #####$\bigtriangledown × H =\dfrac{1}{c} \dfrac{\partial E}{\partial t}$
#
# ###**12. Second law of thermodynamics**
# $dS \geq 0$
#
# ###**13. Relativity**
# $E =mc^2$
#
# ###**14. Schrodingers equations**
# $ih \frac{\partial}{\partial t}\Psi H=\Psi $
#
# ###**15. Information theory**
# $H=-\sum P(x) log p(x)$
#
# ###**16. Chaos theory**
# $x_t+1=kx_1(1-x_t)$
#
# ###**17. Black scholes equation**
# $\frac {1}{2}a^2S^2 \frac{\partial^2v}{\partial S^2}+rS\frac {\partial V}{\partial S}+\frac {\partial V}{\partial t}- rV=0$
#
# ###**18. Cuadratica**
# $\dfrac{-b \pm \sqrt{b^2-4ac}}{2a}$

# %%
# Out:
# 'hola'
